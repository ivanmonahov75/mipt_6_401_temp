# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data_deg = np.concatenate((np.linspace(1, 10, 10), np.linspace(12, 30, 10)))
data_v1 = np.array([54, 39, 29, 25, 23, 19, 18.5, 18, 15, 15, 16, 16, 16, 14, 14, 14, 15, 18, 16, 15])
data_cos = np.array([np.cos(x*np.pi/180)**2 for x in data_cos2])

# %%
plt.plot(data_cos, data_v1)

# %%
freqs = np.loadtxt("freq.txt")
maximums_data = np.loadtxt("maximums.txt")

orders = np.arange(-2, 3, 1)

# Настройки "ГОСТ-стиля"
plt.rcParams.update({
    "font.family": "serif",
    "font.size": 12,
    "axes.labelsize": 12,
    "legend.fontsize": 10,
    "xtick.direction": "in",
    "ytick.direction": "in",
})


plt.plot(data_cos2, data_v1, marker='o', linestyle='--')


# Подписи осей
plt.xlabel("Грудусы поворота")
plt.ylabel("Напряжение, мВ")

# Сетка (тонкая, как обычно требуют)
plt.grid(True, linestyle='--', linewidth=0.5)

# Деления с обеих сторон
plt.tick_params(top=True, right=True)

# Легенда без рамки
# plt.legend(frameon=False)

# Подгонка полей
plt.tight_layout()
plt.title("Зависимость сигнала от угла поворота") 
plt.savefig("graph1.pdf")

# %%
df = pd.read_excel('461.xlsx')

# %%
x_1, v_1 = df.to_numpy().T

# %%
freqs = np.loadtxt("freq.txt")
maximums_data = np.loadtxt("maximums.txt")

orders = np.arange(-2, 3, 1)

# Настройки "ГОСТ-стиля"
plt.rcParams.update({
    "font.family": "serif",
    "font.size": 12,
    "axes.labelsize": 12,
    "legend.fontsize": 10,
    "xtick.direction": "in",
    "ytick.direction": "in",
})


plt.plot(x_1, v_1, marker='.', linestyle='')


# Подписи осей
plt.xlabel("x, мм")
plt.ylabel(r"$I \cdot k$, мВ")

# Сетка (тонкая, как обычно требуют)
plt.grid(True, linestyle='--', linewidth=0.5)

# Деления с обеих сторон
plt.tick_params(top=True, right=True)

# Легенда без рамки
# plt.legend(frameon=False)

# Подгонка полей
plt.tight_layout()
plt.title("Зависимость сигнала от смещения зеркала") 
plt.savefig("graph2.pdf")

# %%
for i in zip(x_1, v_1): #125 соток 517.5
    # print(i)
    pass

# %%
df = pd.read_excel('461.xlsx', sheet_name="Sheet2")

# %%
x_2, v_2 = (df.to_numpy()).T

# %%
# Настройки "ГОСТ-стиля"
plt.rcParams.update({
    "font.family": "serif",
    "font.size": 12,
    "axes.labelsize": 12,
    "legend.fontsize": 10,
    "xtick.direction": "in",
    "ytick.direction": "in",
})


plt.plot(x_2, v_2, marker='.', linestyle='')


# Подписи осей
plt.xlabel("x, мм")
plt.ylabel(r"$I \cdot k$, мВ")

# Сетка (тонкая, как обычно требуют)
plt.grid(True, linestyle='--', linewidth=0.5)

# Деления с обеих сторон
plt.tick_params(top=True, right=True)

# Легенда без рамки
# plt.legend(frameon=False)

# Подгонка полей
plt.tight_layout()
plt.title("Зависимость сигнала от смещения зеркала") 
plt.savefig("graph3.pdf")

# %%
for i in zip(x_2, v_2): # 0, 425
    print(i)
# Out:
# (np.int64(30), np.int64(34))
# (np.int64(35), np.int64(34))
# (np.int64(40), np.int64(33))
# (np.int64(45), np.int64(32))
# (np.int64(50), np.int64(31))
# (np.int64(55), np.int64(30))
# (np.int64(60), np.int64(29))
# (np.int64(65), np.int64(27))
# (np.int64(70), np.int64(27))
# (np.int64(75), np.int64(26))
# (np.int64(80), np.int64(25))
# (np.int64(85), np.int64(24))
# (np.int64(90), np.int64(22))
# (np.int64(95), np.int64(21))
# (np.int64(100), np.int64(20))
# (np.int64(105), np.int64(20))
# (np.int64(110), np.int64(19))
# (np.int64(115), np.int64(16))
# (np.int64(120), np.int64(15))
# (np.int64(125), np.int64(14))
# (np.int64(130), np.int64(12))
# (np.int64(135), np.int64(10))
# (np.int64(140), np.int64(9))
# (np.int64(145), np.int64(8))
# (np.int64(150), np.int64(5))
# (np.int64(155), np.int64(4))
# (np.int64(160), np.int64(3))
# (np.int64(165), np.int64(2))
# (np.int64(170), np.int64(2))
# (np.int64(175), np.int64(2))
# (np.int64(180), np.int64(1))
# (np.int64(185), np.int64(1))
# ...
