# %%
import numpy as np

# %%
length = np.array([280/3, 278/3, 250/8, 224/7, 266/18])

# %%
sinuses =  (length)/np.sqrt(np.square(length) + 1254**2)

# %%
532*10**-9/sinuses * 10**6
# Out:
# array([ 7.16757064,  7.21885283, 21.35472376, 20.85453677, 45.14713457])

# %%
delta_x = (3 * 1254**2) / ( np.sqrt(np.square(length) + 1254**2) * np.square(length))
delta_a = (5 * 1254) / ( np.sqrt(np.square(length) + 1254**2) * np.square(length))

# %%
sigma = 532*10**-6 * np.sqrt(np.square(delta_a) + np.square(delta_x))

# %%
np.asin(sinuses) * 100
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 np.asin(sinuses) * 100
#
# NameError: name 'np' is not defined

# %%
a_1 = np.array([160, 160, 165, 169])
a_2 = 25
ba = np.array([524, 524, 519, 515])
b_2 = 585
d_proj = np.array([0.625, 0.667, 2, 2])

# %%
g = (ba - a_2)*b_2/(a_2*a_1)
np.round(g, 2)
# Out:
# array([72.98, 72.98, 70.06, 67.85])

# %%
np.round(d_proj * g * np.sqrt((0.2/16)**2 + np.square(8/b_2) + np.square(8/a_1) + np.square(8/ba)), 2)
# Out:
# array([2.53, 2.7 , 7.59, 7.21])
