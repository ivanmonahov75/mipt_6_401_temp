# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
pd.read_csv("IV_merged.csv")
data = np.load("IV_merged.npy").T
data[0].shape
# Out:
# (301,)

# %%
for i in range(6):
    plt.plot(data[0], np.log(data[i+1]))
plt.show()
for i in range(6):
    plt.plot(data[0], (data[i+1]))

# %%
for i in range(7, 13):
    plt.plot(data[0], np.log(data[i]))
plt.show()
for i in range(7, 13):
    plt.plot(data[0], (data[i]))

# %%
i = [0.1, 0.8, 1, 1.2, 1.4, 1.6]
